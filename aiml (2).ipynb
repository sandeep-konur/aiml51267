# %%
import pandas as pd

# %%
d=pd.read_csv('/content/drive/MyDrive/Folds5x2_pp.csv')

# %%
print(d)
# Out:
#          AT      V       AP     RH      PE
# 0     14.96  41.76  1024.07  73.17  463.26
# 1     25.18  62.96  1020.04  59.08  444.37
# 2      5.11  39.40  1012.16  92.14  488.56
# 3     20.86  57.32  1010.24  76.64  446.48
# 4     10.82  37.50  1009.23  96.62  473.90
# ...     ...    ...      ...    ...     ...
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28
#
# [9568 rows x 5 columns]

# %%
x1=d['AT'] 
x2=d['V'] 
x3=d['AP']
x4=d['RH']
y=d['PE'] 

print(x1,x2,x3,x4,y)
# Out:
# 0       14.96
# 1       25.18
# 2        5.11
# 3       20.86
# 4       10.82
#         ...
# 9563    16.65
# 9564    13.19
# 9565    31.32
# 9566    24.48
# 9567    21.60
# Name: AT, Length: 9568, dtype: float64 0       41.76
# 1       62.96
# 2       39.40
# 3       57.32
# 4       37.50
#         ...
# 9563    49.69
# 9564    39.18
# 9565    74.33
# 9566    69.45
# 9567    62.52
# Name: V, Length: 9568, dtype: float64 0       1024.07
# 1       1020.04
# 2       1012.16
# 3       1010.24
# 4       1009.23
#          ...
# 9563    1014.01
# 9564    1023.67
# 9565    1012.92
# 9566    1013.86
# 9567    1017.23
# Name: AP, Length: 9568, dtype: float64 0       73.17
# 1       59.08
# 2       92.14
# 3       76.64
# 4       96.62
#         ...
# 9563    91.00
# 9564    66.78
# 9565    36.48
# 9566    62.39
# 9567    67.87
# Name: RH, Length: 9568, dtype: float64 0       463.26
# 1       444.37
# 2       488.56
# 3       446.48
# 4       473.90
#          ...
# 9563    460.03
# ...

# %%
from matplotlib import pyplot as pt
pt.scatter(x1,y)

# %%
pt.scatter(x2,y)

# %%
pt.scatter(x3,y)

# %%
pt.scatter(x4,y)

# %%
pt.scatter(x1,x2)
